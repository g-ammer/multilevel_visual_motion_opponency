# %%
# Python_version 2.7.15

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import os
import scipy.io
from scipy import stats
# %matplotlib inline
import octopus as oct

# %%
# Import Data
time = np.load('time.npy')

R24E09_Ftrace_mean = np.load('R24E09_Ftrace_mean.npy')
R24E09_ArcLight_MOI = np.load('R24E09_MOI.npy')
R24E09_ArcLight_LDir = np.load('R24E09_LDir.npy')
R24E09_R_deg = np.load('R24E09_R_deg.npy')

R20D01_Ftrace_mean = np.load('R20D01_Ftrace_mean.npy')
R20D01_ArcLight_MOI = np.load('R20D01_MOI.npy')
R20D01_ArcLight_LDir = np.load('R20D01_LDir.npy')
R20D01_R_deg = np.load('R20D01_R_deg.npy')

R38G02_Ftrace_mean = np.load('R38G02_Ftrace_mean.npy')
R38G02_ArcLight_MOI = np.load('R38G02_MOI.npy')
R38G02_ArcLight_LDir = np.load('R38G02_LDir.npy')
R38G02_R_deg = np.load('R38G02_R_deg.npy')

SplitT4c_Ftrace_mean = np.load('SplitT4c_Ftrace_mean.npy')
SplitT4c_ArcLight_MOI = np.load('SplitT4c_MOI.npy')
SplitT4c_ArcLight_LDir = np.load('SplitT4c_LDir.npy')
SplitT4c_R_deg = np.load('SplitT4c_R_deg.npy')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-6de514db156f> in <module>()
#       2 time = np.load('time.npy')
#       3
# ----> 4 R24E09_Ftrace_mean = np.load('R24E09_Ftrace_mean.npy')
#       5 R24E09_ArcLight_MOI = np.load('R24E09_MOI.npy')
#       6 R24E09_ArcLight_LDir = np.load('R24E09_LDir.npy')
#
# C:\Users\gammer\AppData\Local\Continuum\anaconda2\lib\site-packages\numpy\lib\npyio.pyc in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# IOError: [Errno 2] No such file or directory: 'R24E09_Ftrace_mean.npy'

# %%
# Import Data
time = np.load('time.npy')

for i in range(len(filenames)):
    a = np.load(filenames[i] + '.npy')
    if(i==0):
        Ftrace_all = a
    if(i==1):
        Ftrace_all = np.stack((Ftrace_all,a), axis=2)   
    if(i>1):
        a = a[:,:,np.newaxis]
        Ftrace_all = np.concatenate((Ftrace_all,a), axis=2)

# %%
fig = plt.figure(figsize = (4, 2.6))

plt.subplots_adjust(wspace=0.1)

alpha=0.35

ax = fig.add_subplot(121)
plt.plot(time,Ftrace_all[:,6,:], color = 'C1', alpha = alpha, linewidth = 1)
plt.plot(time,np.mean(Ftrace_all[:,6,:], axis=1), color = 'C1', linewidth = 2.5)
plt.axvspan(0, 1, facecolor='0.2', alpha=0.2)
plt.xlim([-1.5,2.5])
plt.ylim([-0.13,0.13])
plt.axis('off') 

ax = fig.add_subplot(122)
plt.plot(time,Ftrace_all[:,2,:], color = 'C1', alpha = alpha, linewidth = 1)
plt.plot(time,np.mean(Ftrace_all[:,2,:], axis=1), color = 'C1', linewidth = 2.5)
plt.axvspan(0, 1, facecolor='0.2', alpha=0.2)
plt.xlim([-1.5,2.5])
plt.ylim([-0.135,0.135])
plt.axis('off')

bbox_inches = 'tight'
#plt.savefig('Fig1_R20D01_Ftraces.pdf',bbox_inches='tight', dpi=600, transparent=True)
plt.show()

# %%
rotations = [0,45,90,135,180,225,270,315,360]
Ftrace_mean = np.zeros([len(rotations),len(filenames)])
Ftrace_sem = np.zeros([len(rotations)])
for i in range(len(rotations)):
    Ftrace_sem[i] = stats.sem(np.mean(Ftrace_all[38:51,i,:],0))
    for j in range(len(filenames)):
        Ftrace_mean[i,j] = np.mean(Ftrace_all[np.int(np.where(time == 0)[0]):51,i,j])

# %%
fig = plt.figure(figsize = (2.3, 2.3))


ax = fig.add_subplot(111) #PLOT directional tuning

ax.axhline(y=0,xmin=0.0001,xmax=0.9999, color='0.05', linestyle=':', linewidth = 1)
plt.plot(rotations, Ftrace_mean, color='C1', linewidth = 1, zorder = 0, alpha=0.35)
plt.plot(rotations, np.mean(Ftrace_mean,1), linewidth = 2.5, color = 'C1')
plt.errorbar(rotations, np.mean(Ftrace_mean,1), yerr = Ftrace_sem, linewidth = 2.5, color = 'C1')

plt.xticks(rotations)
ax.set_xticklabels(rotations)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines['left'].set_position(('outward', 7))
ax.spines['bottom'].set_position(('outward', 7))
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(0.5)
ax.set_xlabel(u'Direction [°]', fontsize = 10)
ax.set_ylabel('-$\Delta F/F$ (%)', fontsize = 10)
yticks = np.array([-0.1,-0.05,0,0.05,0.1])
ax.set_yticks(yticks)
ax.set_yticklabels(('-10','-5','0','5','10'), size=10)
xticks = np.array([0,90,180,270,360])
ax.set_xticklabels(xticks, size=10)
ax.set_xticks(xticks)
ax.tick_params(axis='both', which='major', labelsize=10)
plt.ylim([-0.14,0.14])

bbox_inches = 'tight'
#plt.savefig('Fig1_R20D01_DirTuning.pdf',bbox_inches='tight', dpi=600, transparent=True)

plt.show()

# %%
###### Input to MOI function
rot_rad = np.radians(rotations[0:8])
radius = np.mean(Ftrace_mean[0:8,:],1)

# %%
MOI_flies = np.empty(len(Ftrace_mean[0,:]))
for i in range(len(Ftrace_mean[0,:])):
    MOI_flies[i] = oct.MOI(rot_rad, Ftrace_mean[0:8,i])
# Out:
# D_magn =0.18731744911888948   D_deg = 46.9513189229171
# H_magn =0.19682310679363896   H_deg = 55.74728889617589
# MOI = 0.9405116998987766
# D_magn =0.11925697422097384   D_deg = 58.82465893170095
# H_magn =0.15119544578180175   H_deg = 61.3925026218984
# MOI = 0.7879683432307787
# D_magn =0.1434416088968232   D_deg = 39.18905108659193
# H_magn =0.1293596531923812   H_deg = 31.34278170056008
# MOI = 0.8933849720612679
# D_magn =0.15691325572036388   D_deg = 40.839020421735476
# H_magn =0.1886874024752015   H_deg = 40.85520606291833
# MOI = 0.831604269288616
# D_magn =0.12748326903927587   D_deg = 57.15898843829414
# H_magn =0.1647106912668138   H_deg = 69.11077886767362
# MOI = 0.7572047120046249
# D_magn =0.11889792872891432   D_deg = 60.067150884610875
# H_magn =0.16677286915642967   H_deg = 60.54782985909311
# MOI = 0.7129081917534751
# D_magn =0.14499850481508336   D_deg = 61.38796597570079
# H_magn =0.16285419383906227   H_deg = 58.16375768482177
# MOI = 0.8889484622521766
# ...

# %%
LDir_flies = np.empty(len(Ftrace_mean[0,:]))
for i in range(len(Ftrace_mean[0,:])):
    LDir_flies[i] = oct.LDir(rot_rad, Ftrace_mean[0:8,i])
# Out:
# R_magn =0.3830101283672968   R_deg = 51.45834730230735
# R_indiv_magn = 0.48900601970727814
# LDir = 0.7832421543533736
# R_magn =0.2703854663003948   R_deg = 60.2602276754503
# R_indiv_magn = 0.38320154717541133
# LDir = 0.7055959671703133
# R_magn =0.2721637216446878   R_deg = 35.46874418279975
# R_indiv_magn = 0.3496414346421709
# LDir = 0.7784080909152682
# R_magn =0.34560065477724683   R_deg = 40.84785728741111
# R_indiv_magn = 0.4777317608364094
# LDir = 0.7234198835182565
# R_magn =0.2906319588565675   R_deg = 63.8989793608003
# R_indiv_magn = 0.3840243102596401
# LDir = 0.7568061476630744
# R_magn =0.2856683551965357   R_deg = 60.347768567281115
# R_indiv_magn = 0.41552300798549835
# LDir = 0.6874910647703664
# R_magn =0.3077312587304699   R_deg = 59.682333973170614
# R_indiv_magn = 0.4421534437954533
# LDir = 0.6959829512779526
# R_magn =0.28256691479856744   R_deg = 62.30858700756975
# R_indiv_magn = 0.38957103577665386
# LDir = 0.7253283454075028
# ...

# %%
R_deg_flies = np.empty(len(Ftrace_mean[0,:]))
for i in range(len(Ftrace_mean[0,:])):
    R_deg_flies[i] = oct.R_deg(rot_rad, Ftrace_mean[0:8,i])

# %%
# Save Ftrace as numpy array

np.save('R20D01_Ftrace_mean.npy', Ftrace_mean)
np.save('R20D01_Ftrace_all.npy', Ftrace_all)
np.save('R20D01_MOI.npy', MOI_flies)
np.save('R20D01_LDir.npy', LDir_flies)
np.save('R20D01_R_deg.npy', R_deg_flies)
